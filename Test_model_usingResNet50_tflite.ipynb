# %% [markdown]
# <a href="https://colab.research.google.com/github/VanBap/Adverse_Weather/blob/master/Test_model_usingResNet50_tflite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell if u can't mount ur drive automatically
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ngô Hoàng Khánh Văn - 20021599

from tensorflow import keras

from tensorflow.keras.models import Model

from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image


import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
import glob
import pathlib
import pandas as pd

# %%
train_data_dir = '/content/drive/MyDrive/KHOA_LUAN/DATASET/DATASET_splitted/train'
valid_data_dir = '/content/drive/MyDrive/KHOA_LUAN/DATASET/DATASET_splitted/val'
test_data_dir = '/content/drive/MyDrive/KHOA_LUAN/DATASET/DATASET_splitted/test'

img_height, img_width = (224, 224)
batch_size = 32

train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True
                                   )
# tạo dữ liệu tăng cường: xoay ảnh = 0.2; phóng to = 0.2; lật ảnh ngang; giữ 40% cho validation

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size = batch_size,
    class_mode='categorical')
    #subset='training') # set as training data

valid_generator = train_datagen.flow_from_directory(
    valid_data_dir,
    target_size=(img_height, img_width),
    batch_size = batch_size,
    class_mode='categorical')
    #subset='validation') # set as validation data

test_generator = train_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_height, img_width),
    batch_size = 1,
    class_mode='categorical')
    #subset='validation') # set as testing data

train_generator.class_indices
valid_generator.class_indices
test_generator.class_indices
# Out:
# Found 1289 images belonging to 7 classes.
# Found 428 images belonging to 7 classes.
# Found 435 images belonging to 7 classes.
# {'Cloudy': 0,
#  'Fog': 1,
#  'Rainy': 2,
#  'Sandy': 3,
#  'Shine': 4,
#  'Snowy': 5,
#  'Sunrise': 6}

# %%
MODEL_TFLITE_NAME_PATH_1 = '/content/drive/MyDrive/KHOA_LUAN/saved_model/ResNet50/ResNet50_checkpoint_optimizing.tflite'
BEST_TFLITE_MODEL_PATH = '/content/drive/MyDrive/KHOA_LUAN/saved_model/ResNet50/ResNet50_checkpoint_optimizing.tflite'

# %% [markdown]
# **Test độ chính xác của model .tflite sau khi được lượng tử hóa float16**

# %%
import tensorflow as tf
import time
import numpy as np

# Load model
model_path = BEST_TFLITE_MODEL_PATH
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
# Resize Tensor Shape
interpreter.resize_tensor_input(input_details[0]['index'], (1, 224, 224, 3))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
# Perform evaluation
print("input_details is: ", input_details)
print("input_details is: ", output_details)
correct_predictions = 0
total_samples = 0
inference_time = 0
average_inference_time = 0
sum_inference_time = 0
for images, labels in test_generator:
    interpreter.set_tensor(input_details[0]['index'], images)

    # Measure inference time and resource usage
    start_time = time.time()
    # Perform inference
    interpreter.invoke()
    end_time = time.time()
    inference_time = end_time - start_time

    sum_inference_time += inference_time

    output_data = interpreter.get_tensor(output_details[0]['index'])
    #predictions = tf.argmax(output_data, axis=1)
    predictions = np.argmax(output_data)

    temp_labels = np.argmax(labels) # convert one-hot encoding to oct
    correct_predictions += tf.cast(tf.equal(predictions, temp_labels), dtype=tf.float32)
    if tf.equal(predictions, temp_labels) == False:
      print("=================================")
      print("! WRONG ANSWER !")
      print('predictions is: ', predictions)
      print('label is: ', labels)
      print('correct_predictions is', correct_predictions)

    else:
      print("=================================")
      print("RIGHT ANSWER")
      print('correct_predictions is', correct_predictions)
    total_samples += len(labels)

    # Thêm điều kiện để thoát khỏi vòng lặp khi đã thử nghiệm hết tất cả các mẫu
    if total_samples >= len(test_generator.filenames):
        break

average_inference_time = sum_inference_time / total_samples
# Out:
# input_details is:  [{'name': 'serving_default_resnet50_input:0', 'index': 0, 'shape': array([  1, 224, 224,   3], dtype=int32), 'shape_signature': array([ -1, 224, 224,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# input_details is:  [{'name': 'StatefulPartitionedCall:0', 'index': 294, 'shape': array([1, 7], dtype=int32), 'shape_signature': array([-1,  7], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(1.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(2.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(3.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(4.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(5.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(6.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(7.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(8.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(9.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(10.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(11.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(12.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(13.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 0. 0. 0. 0. 1. 0.]]
# correct_predictions is tf.Tensor(13.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(14.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(15.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(15.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(16.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 0. 0. 0. 1. 0. 0.]]
# correct_predictions is tf.Tensor(16.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(17.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(18.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(19.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(20.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(21.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(22.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(23.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(24.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(25.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(26.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(26.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(27.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(27.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(28.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(29.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(30.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(31.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(32.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(33.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(34.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(35.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(36.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(37.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(38.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(39.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(40.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(41.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(41.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(42.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(43.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(44.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(45.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(46.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(47.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(48.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(49.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(50.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(51.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(52.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(53.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(54.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(55.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(56.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(57.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(57.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(58.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(59.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(60.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(61.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 0. 0. 1. 0. 0.]]
# correct_predictions is tf.Tensor(61.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(62.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(63.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(64.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(65.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(66.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(67.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(68.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(69.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(70.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(71.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(72.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(72.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(72.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(72.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(73.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(74.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(75.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(76.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(77.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(78.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(79.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(80.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(81.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(81.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(82.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(83.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(84.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(85.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(86.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(87.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(88.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(89.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(90.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(91.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(91.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(92.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(93.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(94.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 0. 0. 0. 1. 0.]]
# correct_predictions is tf.Tensor(94.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(95.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(96.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(97.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(98.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(99.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(100.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  4
# label is:  [[1. 0. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(100.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(101.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(102.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(103.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(104.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(105.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  4
# label is:  [[1. 0. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(105.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(106.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  5
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(106.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(107.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(108.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(109.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(109.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(110.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(111.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(112.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(113.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(114.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(115.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(116.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(117.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(118.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(119.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(120.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(121.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(122.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(123.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(124.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(125.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(126.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(127.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(128.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(129.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(130.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(131.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(132.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(133.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(134.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(135.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(136.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(137.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(138.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(139.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(140.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(141.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(142.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(143.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(144.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(145.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(146.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 0. 0. 0. 0. 1. 0.]]
# correct_predictions is tf.Tensor(146.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(147.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(148.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(149.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(150.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(150.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(151.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(152.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(153.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(154.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(155.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(156.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(157.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(158.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(159.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(160.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(161.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(161.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(162.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(163.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(164.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(165.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(166.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(167.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(168.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(169.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(170.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(171.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(172.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(173.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(174.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(175.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(176.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(177.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(178.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(179.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(180.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(181.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(182.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(183.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(184.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(184.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(185.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(186.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(187.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(188.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(189.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(190.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(191.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(192.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(193.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(194.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(195.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(196.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(197.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(197.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(198.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(199.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(200.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(201.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(202.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(203.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(204.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(205.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(205.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(205.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(206.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(206.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(207.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(208.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(209.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(210.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(211.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(212.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(213.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(214.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(214.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(214.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(215.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(216.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(217.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(218.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(219.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(220.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(221.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(222.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(223.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(224.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(225.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(226.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(227.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(228.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(229.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(230.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(231.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(232.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(233.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(234.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(235.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(236.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(237.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(238.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(239.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(240.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(241.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(242.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(243.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(244.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(245.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(246.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(247.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  4
# label is:  [[1. 0. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(247.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(248.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(249.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(250.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(251.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(251.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(252.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(253.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(254.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(255.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(256.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(257.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(258.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(259.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(259.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(260.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(261.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(262.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(263.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(264.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(265.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(266.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(267.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(268.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(269.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(270.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(270.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(271.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(272.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(273.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(274.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(275.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 0. 0. 1. 0. 0.]]
# correct_predictions is tf.Tensor(275.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(276.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(277.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(278.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(279.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(280.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(281.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  4
# label is:  [[1. 0. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(281.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(282.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(283.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(284.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(285.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(286.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  3
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(286.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(287.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(288.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(289.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(290.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(291.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(292.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(293.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(294.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(295.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(296.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(296.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(297.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(298.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(299.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(300.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(300.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(301.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(302.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(303.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 1. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(303.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(304.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(305.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(306.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  1
# label is:  [[0. 0. 0. 1. 0. 0. 0.]]
# correct_predictions is tf.Tensor(306.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(307.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(308.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(309.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(310.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(311.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(312.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(313.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(314.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(315.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(316.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(317.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(318.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(319.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(320.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(321.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(322.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(323.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(324.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(325.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(326.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(327.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(328.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(329.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(330.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 0. 0. 1. 0. 0.]]
# correct_predictions is tf.Tensor(330.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(331.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(332.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(333.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(334.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(335.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(336.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(337.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(338.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(339.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(340.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(341.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(342.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(343.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(344.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(345.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(346.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(347.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(348.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(349.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(350.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(351.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(352.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(353.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(354.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(355.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(356.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(357.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(358.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(359.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(360.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(361.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(362.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(363.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(364.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(365.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(366.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(367.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(368.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(369.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(370.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(371.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(372.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(373.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(373.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(374.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(375.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  0
# label is:  [[0. 0. 0. 0. 0. 0. 1.]]
# correct_predictions is tf.Tensor(375.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(376.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(377.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(378.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(379.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(380.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(381.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(382.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(383.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(384.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(385.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(386.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(387.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(388.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(389.0, shape=(), dtype=float32)
# =================================
# ! WRONG ANSWER !
# predictions is:  2
# label is:  [[0. 1. 0. 0. 0. 0. 0.]]
# correct_predictions is tf.Tensor(389.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(390.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(391.0, shape=(), dtype=float32)
# =================================
# RIGHT ANSWER
# correct_predictions is tf.Tensor(392.0, shape=(), dtype=float32)

# %%
# Calculate accuracy
test_accuracy = correct_predictions / total_samples
print('Total samples:', total_samples)
print('Correct predictions:', correct_predictions)
print('Test accuracy:', test_accuracy.numpy())
print('Interfernce time:', inference_time)
print('Average interfernce time:', average_inference_time)
# Out:
# Total samples: 435
# Correct predictions: tf.Tensor(392.0, shape=(), dtype=float32)
# Test accuracy: 0.90114945
# Interfernce time: 0.24456191062927246
# Average interfernce time: 0.16928644728386538
